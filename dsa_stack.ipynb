# %%
# Out:
# 3

# %%
class StackArray:
    def __init__(self):
        self.stack = []
    
    def push(self, item):
        self.stack.append(item)
    
    def pop(self):
        if self.is_empty():
            raise IndexError("pop from empty stack")
        return self.stack.pop()
    
    def peek(self):
        if self.is_empty():
            raise IndexError("peek from empty stack")
        return self.stack[-1]
    
    def is_empty(self):
        return len(self.stack) == 0
    
    def size(self):
        return len(self.stack)  
    def __len__(self):
        return len(self.stack)

# %%
class Stack2:
    def __init__(self):
        self.stack = []
    def push(self, item):
        self.stack.append(item)
    def pop(self):
        if self.is_empty():
            raise IndexError("pop from empty stack")
        return self.stack.pop()
    def peek(self):
        if self.is_empty():
            raise IndexError("peek from empty stack")
        return self.stack[-1]
    def is_empty(self):
        return len(self.stack) == 0
    def size(self):
        return len(self.stack)
    def __len__(self):
        return len(self.stack)

# %%
#selecttion sort algorithms 
#lets make list or arr
arr = [1,3,5,39,55,23,0,4]
len(arr)


def selection_sort(arr):
    n= len(arr)
    for i in range(n-1)
# Out:
# 8

# %%
import matplotlib.pyplot as plt

# Full DSA Structure Text
dsa_structure = """
DSA
│
├── DATA STRUCTURES
│   │
│   ├── Linear Data Structures
│   │   │
│   │   ├── Static
│   │   │   ├── Array
│   │   │   └── String
│   │   │
│   │   └── Dynamic
│   │       ├── Linked List
│   │       ├── Stack
│   │       ├── Queue
│   │       └── Deque
│   │
│   └── Non-Linear Data Structures
│       │
│       ├── Tree (Dynamic)
│       │   ├── Binary Tree
│       │   ├── Binary Search Tree (BST)
│       │   ├── Heap
│       │   ├── AVL Tree
│       │   ├── Segment Tree
│       │   └── Trie
│       │
│       ├── Graph (Dynamic)
│       │   ├── Directed Graph
│       │   ├── Undirected Graph
│       │   └── Weighted Graph
│       │
│       └── Hashing (Dynamic)
│           ├── Hash Table
│           ├── Hash Map
│           └── Hash Set
│
└── ALGORITHMS
    │
    ├── Searching Algorithms
    │   ├── Linear Search
    │   └── Binary Search
    │
    ├── Sorting Algorithms
    │   ├── Bubble Sort
    │   ├── Selection Sort
    │   ├── Insertion Sort
    │   ├── Merge Sort
    │   ├── Quick Sort
    │   └── Heap Sort
    │
    ├── Tree Algorithms
    │   ├── DFS (Depth First Search)
    │   │   ├── Preorder Traversal
    │   │   ├── Inorder Traversal
    │   │   └── Postorder Traversal
    │   │
    │   └── BFS (Level Order Traversal)
    │
    ├── Graph Algorithms
    │   ├── BFS
    │   ├── DFS
    │   ├── Dijkstra
    │   ├── Bellman-Ford
    │   ├── Floyd Warshall
    │   ├── Kruskal (Minimum Spanning Tree)
    │   └── Prim (Minimum Spanning Tree)
    │
    ├── Recursion
    │   ├── Factorial
    │   └── Fibonacci
    │
    ├── Backtracking
    │   ├── N-Queens
    │   ├── Sudoku Solver
    │   └── Subsets / Permutations
    │
    ├── Greedy Algorithms
    │   ├── Activity Selection
    │   ├── Huffman Coding
    │   └── Fractional Knapsack
    │
    ├── Dynamic Programming
    │   ├── 0/1 Knapsack
    │   ├── Longest Common Subsequence
    │   ├── Matrix Chain Multiplication
    │   └── DP on Trees / Graphs
    │
    ├── Two Pointer Technique
    ├── Sliding Window Technique
    ├── Bit Manipulation
    ├── Divide & Conquer
    └── Mathematical Algorithms
"""

# Create figure
plt.figure(figsize=(14, 22))
plt.text(0.01, 0.99, dsa_structure, fontsize=10, family='monospace', verticalalignment='top')
plt.axis('off')

# Save as JPEG
plt.savefig("DSA_Master_Structure.jpeg", format="jpeg", dpi=300, bbox_inches="tight")
plt.close()

print("Image saved as DSA_Master_Structure.jpeg")
# Out:
# Image saved as DSA_Master_Structure.jpeg

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch

# Create figure (Landscape)
fig, ax = plt.subplots(figsize=(24, 14))
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
ax.axis('off')

def draw_box(text, x, y, width=18, height=4, fontsize=9):
    box = FancyBboxPatch(
        (x, y),
        width,
        height,
        boxstyle="round,pad=0.3,rounding_size=1.5",
        edgecolor="black",
        facecolor="#f2f2f2",
        linewidth=1
    )
    ax.add_patch(box)
    ax.text(
        x + width / 2,
        y + height / 2,
        text,
        ha='center',
        va='center',
        fontsize=fontsize,
        wrap=True
    )

# =========================
# ROOT
# =========================
draw_box("DSA", 40, 94, 20, 5, 14)

# =========================
# DATA STRUCTURES
# =========================
draw_box("DATA STRUCTURES", 10, 88, 30, 5, 12)

# Linear
draw_box("Linear DS", 5, 82)
draw_box("Static", 2, 76)
draw_box("Array", 0, 70)
draw_box("String", 4, 70)

draw_box("Dynamic", 8, 76)
draw_box("Linked List", 6, 70)
draw_box("Stack", 10, 70)
draw_box("Queue", 14, 70)
draw_box("Deque", 18, 70)

# Non Linear
draw_box("Non-Linear DS", 30, 82)

# Tree
draw_box("Tree (Dynamic)", 26, 76)
draw_box("Binary Tree", 22, 70)
draw_box("BST", 26, 70)
draw_box("Heap", 30, 70)
draw_box("AVL Tree", 34, 70)
draw_box("Segment Tree", 38, 70)
draw_box("Trie", 42, 70)

# Graph
draw_box("Graph (Dynamic)", 30, 64)
draw_box("Directed", 26, 58)
draw_box("Undirected", 30, 58)
draw_box("Weighted", 34, 58)

# Hashing
draw_box("Hashing", 30, 52)
draw_box("Hash Table", 26, 46)
draw_box("Hash Map", 30, 46)
draw_box("Hash Set", 34, 46)

# =========================
# ALGORITHMS
# =========================
draw_box("ALGORITHMS", 60, 88, 30, 5, 12)

# Searching
draw_box("Searching", 55, 82)
draw_box("Linear Search", 52, 76)
draw_box("Binary Search", 58, 76)

# Sorting
draw_box("Sorting", 70, 82)
draw_box("Bubble", 66, 76)
draw_box("Selection", 70, 76)
draw_box("Insertion", 74, 76)
draw_box("Merge", 66, 70)
draw_box("Quick", 70, 70)
draw_box("Heap Sort", 74, 70)

# Tree Algorithms
draw_box("Tree Algorithms", 55, 64)
draw_box("DFS", 52, 58)
draw_box("Preorder", 48, 52)
draw_box("Inorder", 52, 52)
draw_box("Postorder", 56, 52)
draw_box("BFS (Level Order)", 60, 58)

# Graph Algorithms
draw_box("Graph Algorithms", 70, 64)
draw_box("BFS", 66, 58)
draw_box("DFS", 70, 58)
draw_box("Dijkstra", 74, 58)
draw_box("Bellman-Ford", 78, 58)
draw_box("Floyd Warshall", 66, 52)
draw_box("Kruskal", 70, 52)
draw_box("Prim", 74, 52)

# Other Techniques
draw_box("Recursion", 55, 44)
draw_box("Backtracking", 60, 44)
draw_box("Greedy", 65, 44)
draw_box("Dynamic Programming", 70, 44)
draw_box("Two Pointer", 55, 38)
draw_box("Sliding Window", 60, 38)
draw_box("Bit Manipulation", 65, 38)
draw_box("Divide & Conquer", 70, 38)
draw_box("Mathematical Algorithms", 75, 38)

# Save as High Resolution JPEG
plt.savefig("DSA_Landscape_Rounded_Boxes.jpeg", dpi=300, bbox_inches="tight")
plt.close()

print("Image saved as DSA_Landscape_Rounded_Boxes.jpeg")
# Out:
# Image saved as DSA_Landscape_Rounded_Boxes.jpeg

# %%
from graphviz import Digraph

# Create graph
dot = Digraph("DSA_Map", format="jpeg")
dot.attr(rankdir="LR", size="16,10")  # Landscape
dot.attr("node", shape="box", style="rounded,filled", fontname="Helvetica")

# =========================
# ROOT
# =========================
dot.node("DSA", fillcolor="#2E86C1", fontcolor="white", fontsize="20")

# =========================
# DATA STRUCTURES
# =========================
dot.node("DS", "DATA STRUCTURES", fillcolor="#5DADE2")
dot.edge("DSA", "DS")

dot.node("Linear", "Linear DS", fillcolor="#AED6F1")
dot.node("NonLinear", "Non-Linear DS", fillcolor="#AED6F1")
dot.edge("DS", "Linear")
dot.edge("DS", "NonLinear")

# Linear children
linear_items = ["Array", "String", "Linked List", "Stack", "Queue", "Deque"]
for item in linear_items:
    dot.node(item, item, fillcolor="#D6EAF8")
    dot.edge("Linear", item)

# Non-Linear children
dot.node("Tree", "Tree", fillcolor="#D6EAF8")
dot.node("Graph", "Graph", fillcolor="#D6EAF8")
dot.node("Hashing", "Hashing", fillcolor="#D6EAF8")
dot.edge("NonLinear", "Tree")
dot.edge("NonLinear", "Graph")
dot.edge("NonLinear", "Hashing")

# Tree children
tree_items = ["Binary Tree", "BST", "Heap", "AVL Tree", "Segment Tree", "Trie"]
for item in tree_items:
    dot.node(item, item, fillcolor="#EBF5FB")
    dot.edge("Tree", item)

# Graph children
graph_items = ["Directed Graph", "Undirected Graph", "Weighted Graph"]
for item in graph_items:
    dot.node(item, item, fillcolor="#EBF5FB")
    dot.edge("Graph", item)

# Hashing children
hash_items = ["Hash Table", "Hash Map", "Hash Set"]
for item in hash_items:
    dot.node(item, item, fillcolor="#EBF5FB")
    dot.edge("Hashing", item)

# =========================
# ALGORITHMS
# =========================
dot.node("Algo", "ALGORITHMS", fillcolor="#F39C12")
dot.edge("DSA", "Algo")

algo_categories = {
    "Searching": ["Linear Search", "Binary Search"],
    "Sorting": ["Bubble Sort", "Selection Sort", "Insertion Sort", "Merge Sort", "Quick Sort", "Heap Sort"],
    "Tree Algorithms": ["DFS", "Preorder", "Inorder", "Postorder", "BFS (Level Order)"],
    "Graph Algorithms": ["BFS", "DFS", "Dijkstra", "Bellman-Ford", "Floyd Warshall", "Kruskal", "Prim"],
    "Recursion": ["Factorial", "Fibonacci"],
    "Backtracking": ["N-Queens", "Sudoku Solver", "Subsets / Permutations"],
    "Greedy": ["Activity Selection", "Huffman Coding", "Fractional Knapsack"],
    "Dynamic Programming": ["0/1 Knapsack", "LCS", "Matrix Chain Multiplication", "DP on Trees/Graphs"],
    "Techniques": ["Two Pointer", "Sliding Window", "Bit Manipulation", "Divide & Conquer", "Mathematical Algorithms"]
}

for category, items in algo_categories.items():
    dot.node(category, category, fillcolor="#F8C471")
    dot.edge("Algo", category)
    for item in items:
        dot.node(item, item, fillcolor="#FDEBD0")
        dot.edge(category, item)

# Render image
dot.render("DSA_Professional_Tree_Map", view=False)

print("Saved as DSA_Professional_Tree_Map.jpeg")
# Out:
# Saved as DSA_Mindmap_Landscape.jpeg

# %%
from graphviz import Digraph

# Create graph
dot = Digraph("DSA_Map", format="jpeg")
dot.attr(rankdir="LR", size="16,10")  # Landscape
dot.attr("node", shape="box", style="rounded,filled", fontname="Helvetica")

# =========================
# ROOT
# =========================
dot.node("DSA", fillcolor="#2E86C1", fontcolor="white", fontsize="20")

# =========================
# DATA STRUCTURES
# =========================
dot.node("DS", "DATA STRUCTURES", fillcolor="#5DADE2")
dot.edge("DSA", "DS")

dot.node("Linear", "Linear DS", fillcolor="#AED6F1")
dot.node("NonLinear", "Non-Linear DS", fillcolor="#AED6F1")
dot.edge("DS", "Linear")
dot.edge("DS", "NonLinear")

# Linear children
linear_items = ["Array", "String", "Linked List", "Stack", "Queue", "Deque"]
for item in linear_items:
    dot.node(item, item, fillcolor="#D6EAF8")
    dot.edge("Linear", item)

# Non-Linear children
dot.node("Tree", "Tree", fillcolor="#D6EAF8")
dot.node("Graph", "Graph", fillcolor="#D6EAF8")
dot.node("Hashing", "Hashing", fillcolor="#D6EAF8")
dot.edge("NonLinear", "Tree")
dot.edge("NonLinear", "Graph")
dot.edge("NonLinear", "Hashing")

# Tree children
tree_items = ["Binary Tree", "BST", "Heap", "AVL Tree", "Segment Tree", "Trie"]
for item in tree_items:
    dot.node(item, item, fillcolor="#EBF5FB")
    dot.edge("Tree", item)

# Graph children
graph_items = ["Directed Graph", "Undirected Graph", "Weighted Graph"]
for item in graph_items:
    dot.node(item, item, fillcolor="#EBF5FB")
    dot.edge("Graph", item)

# Hashing children
hash_items = ["Hash Table", "Hash Map", "Hash Set"]
for item in hash_items:
    dot.node(item, item, fillcolor="#EBF5FB")
    dot.edge("Hashing", item)

# =========================
# ALGORITHMS
# =========================
dot.node("Algo", "ALGORITHMS", fillcolor="#F39C12")
dot.edge("DSA", "Algo")

algo_categories = {
    "Searching": ["Linear Search", "Binary Search"],
    "Sorting": ["Bubble Sort", "Selection Sort", "Insertion Sort", "Merge Sort", "Quick Sort", "Heap Sort"],
    "Tree Algorithms": ["DFS", "Preorder", "Inorder", "Postorder", "BFS (Level Order)"],
    "Graph Algorithms": ["BFS", "DFS", "Dijkstra", "Bellman-Ford", "Floyd Warshall", "Kruskal", "Prim"],
    "Recursion": ["Factorial", "Fibonacci"],
    "Backtracking": ["N-Queens", "Sudoku Solver", "Subsets / Permutations"],
    "Greedy": ["Activity Selection", "Huffman Coding", "Fractional Knapsack"],
    "Dynamic Programming": ["0/1 Knapsack", "LCS", "Matrix Chain Multiplication", "DP on Trees/Graphs"],
    "Techniques": ["Two Pointer", "Sliding Window", "Bit Manipulation", "Divide & Conquer", "Mathematical Algorithms"]
}

for category, items in algo_categories.items():
    dot.node(category, category, fillcolor="#F8C471")
    dot.edge("Algo", category)
    for item in items:
        dot.node(item, item, fillcolor="#FDEBD0")
        dot.edge(category, item)

# Render image
dot.render("DSA_Professional_Tree_Map", view=False)

print("Saved as DSA_Professional_Tree_Map.jpeg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/graphviz/backend/execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#
# ...

# %%
# !pip install graphviz
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.8 kB/s  0:00:27 eta 0:00:03m
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install networkx matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.6 kB/s  0:00:25 eta 0:00:03
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create directed graph
G = nx.DiGraph()

# -----------------------
# Define Structure
# -----------------------
structure = {
    "DSA": ["DATA STRUCTURES", "ALGORITHMS"],

    "DATA STRUCTURES": ["Linear DS", "Non-Linear DS"],
    "Linear DS": ["Array", "String", "Linked List", "Stack", "Queue", "Deque"],
    "Non-Linear DS": ["Tree", "Graph", "Hashing"],

    "Tree": ["Binary Tree", "BST", "Heap", "AVL Tree", "Segment Tree", "Trie"],
    "Graph": ["Directed Graph", "Undirected Graph", "Weighted Graph"],
    "Hashing": ["Hash Table", "Hash Map", "Hash Set"],

    "ALGORITHMS": [
        "Searching", "Sorting", "Tree Algorithms",
        "Graph Algorithms", "Recursion", "Backtracking",
        "Greedy", "Dynamic Programming", "Techniques"
    ],

    "Searching": ["Linear Search", "Binary Search"],
    "Sorting": ["Bubble Sort", "Selection Sort", "Insertion Sort", "Merge Sort", "Quick Sort", "Heap Sort"],
    "Tree Algorithms": ["DFS", "Preorder", "Inorder", "Postorder", "BFS (Level Order)"],
    "Graph Algorithms": ["BFS", "DFS", "Dijkstra", "Bellman-Ford", "Floyd Warshall", "Kruskal", "Prim"],
    "Recursion": ["Factorial", "Fibonacci"],
    "Backtracking": ["N-Queens", "Sudoku Solver", "Subsets / Permutations"],
    "Greedy": ["Activity Selection", "Huffman Coding", "Fractional Knapsack"],
    "Dynamic Programming": ["0/1 Knapsack", "LCS", "Matrix Chain Multiplication", "DP on Trees/Graphs"],
    "Techniques": ["Two Pointer", "Sliding Window", "Bit Manipulation", "Divide & Conquer", "Mathematical Algorithms"]
}

# Add edges
for parent, children in structure.items():
    for child in children:
        G.add_edge(parent, child)

# -----------------------
# Custom Layout (Hierarchical)
# -----------------------
pos = nx.spring_layout(G, k=1.2, iterations=100)

# -----------------------
# Color Mapping
# -----------------------
color_map = []
for node in G:
    if node == "DSA":
        color_map.append("#1f78b4")
    elif node in structure["DSA"]:
        color_map.append("#33a02c")
    elif node in structure["DATA STRUCTURES"] or node in structure["ALGORITHMS"]:
        color_map.append("#ff7f00")
    else:
        color_map.append("#a6cee3")

# -----------------------
# Draw Graph
# -----------------------
plt.figure(figsize=(28, 18))  # Landscape

nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=4000,
    node_color=color_map,
    font_size=8,
    font_weight="bold",
    edge_color="gray",
    arrows=False
)

plt.title("Complete DSA Structure", fontsize=22)
plt.savefig("DSA_Professional_Tree_NetworkX.jpeg", dpi=300, bbox_inches="tight")
plt.close()

print("Saved as DSA_Professional_Tree_NetworkX.jpeg")
# Out:
# Saved as DSA_Professional_Tree_NetworkX.jpeg

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch

# ----------- TREE STRUCTURE -----------
structure = {
    "DSA": {
        "DATA STRUCTURES": {
            "Linear DS": {
                "Static": ["Array", "String"],
                "Dynamic": ["Linked List", "Stack", "Queue", "Deque"]
            },
            "Non-Linear DS": {
                "Tree": ["Binary Tree", "BST", "Heap", "AVL Tree", "Segment Tree", "Trie"],
                "Graph": ["Directed Graph", "Undirected Graph", "Weighted Graph"],
                "Hashing": ["Hash Table", "Hash Map", "Hash Set"]
            }
        },
        "ALGORITHMS": {
            "Searching": ["Linear Search", "Binary Search"],
            "Sorting": ["Bubble Sort", "Selection Sort", "Insertion Sort", "Merge Sort", "Quick Sort", "Heap Sort"],
            "Tree Algorithms": ["DFS", "Preorder", "Inorder", "Postorder", "BFS (Level Order)"],
            "Graph Algorithms": ["BFS", "DFS", "Dijkstra", "Bellman-Ford", "Floyd Warshall", "Kruskal", "Prim"],
            "Recursion": ["Factorial", "Fibonacci"],
            "Backtracking": ["N-Queens", "Sudoku Solver", "Subsets / Permutations"],
            "Greedy": ["Activity Selection", "Huffman Coding", "Fractional Knapsack"],
            "Dynamic Programming": ["0/1 Knapsack", "LCS", "Matrix Chain Multiplication", "DP on Trees/Graphs"],
            "Techniques": ["Two Pointer", "Sliding Window", "Bit Manipulation", "Divide & Conquer", "Mathematical Algorithms"]
        }
    }
}

# ----------- DRAWING ENGINE -----------

fig, ax = plt.subplots(figsize=(32, 20))
ax.set_xlim(0, 200)
ax.set_ylim(0, 200)
ax.axis('off')

def draw_box(text, x, y, color, width=22, height=6):
    box = FancyBboxPatch(
        (x, y),
        width,
        height,
        boxstyle="round,pad=0.4,rounding_size=2",
        edgecolor="black",
        facecolor=color,
        linewidth=1.2
    )
    ax.add_patch(box)
    ax.text(x + width/2, y + height/2, text,
            ha='center', va='center', fontsize=8, weight='bold')
    return (x + width/2, y)

def connect(parent, child):
    ax.plot([parent[0], child[0]], [parent[1], child[1]], color="gray")

# ----------- ROOT -----------
root = draw_box("DSA", 85, 185, "#1F77B4")

# ----------- LEVEL 1 -----------
ds = draw_box("DATA STRUCTURES", 30, 160, "#2CA02C")
algo = draw_box("ALGORITHMS", 120, 160, "#FF7F0E")

connect(root, (41, 166))
connect(root, (131, 166))

# ----------- DATA STRUCTURES -----------
linear = draw_box("Linear DS", 10, 135, "#98DF8A")
nonlinear = draw_box("Non-Linear DS", 60, 135, "#98DF8A")

connect((41,160), (21,141))
connect((41,160), (71,141))

# Linear children
static = draw_box("Static", 0, 110, "#C7E9C0")
dynamic = draw_box("Dynamic", 20, 110, "#C7E9C0")

connect((21,135), (11,116))
connect((21,135), (31,116))

# Static items
array = draw_box("Array", -10, 85, "#E5F5E0")
string = draw_box("String", 10, 85, "#E5F5E0")

connect((11,110), (1,91))
connect((11,110), (21,91))

# Dynamic items
items = ["Linked List", "Stack", "Queue", "Deque"]
x_pos = 20
for item in items:
    child = draw_box(item, x_pos, 85, "#E5F5E0")
    connect((31,110), (x_pos+11,91))
    x_pos += 22

# ----------- ALGORITHMS -----------
categories = list(structure["DSA"]["ALGORITHMS"].keys())
x_start = 110
for cat in categories:
    cat_box = draw_box(cat, x_start, 135, "#FDBF6F")
    connect((131,160), (x_start+11,141))

    y_child = 110
    x_child = x_start
    for sub in structure["DSA"]["ALGORITHMS"][cat]:
        sub_box = draw_box(sub, x_child, y_child, "#FFE0B2")
        connect((x_start+11,135), (x_child+11,116))
        y_child -= 22
    x_start += 28

# ----------- SAVE -----------
plt.savefig("DSA_Clean_Hierarchical_Tree.jpeg", dpi=300, bbox_inches="tight")
plt.close()

print("Saved as DSA_Clean_Hierarchical_Tree.jpeg")
# Out:
# Saved as DSA_Clean_Hierarchical_Tree.jpeg

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch

# ---------- FIGURE ----------
fig, ax = plt.subplots(figsize=(32, 20))
ax.set_xlim(0, 200)
ax.set_ylim(0, 200)
ax.axis('off')

# ---------- DRAW BOX ----------
def draw_box(text, x, y, color, width=24, height=6):
    box = FancyBboxPatch(
        (x, y),
        width,
        height,
        boxstyle="round,pad=0.4,rounding_size=2",
        edgecolor="black",
        facecolor=color,
        linewidth=1.5
    )
    ax.add_patch(box)
    ax.text(x + width/2, y + height/2, text,
            ha='center', va='center',
            fontsize=9, weight='bold')
    return (x + width/2, y)  # return bottom center

# ---------- CONNECT WITH ARROW ----------
def connect(parent, child):
    ax.annotate(
        "",
        xy=child,
        xytext=parent,
        arrowprops=dict(
            arrowstyle="->",
            linewidth=1.4,
            color="gray"
        )
    )

# ---------- ROOT ----------
root = draw_box("DSA", 85, 185, "#1F77B4")

# ---------- LEVEL 1 ----------
ds = draw_box("DATA STRUCTURES", 30, 160, "#2CA02C")
algo = draw_box("ALGORITHMS", 120, 160, "#FF7F0E")

connect(root, (42, 166))
connect(root, (132, 166))

# ---------- DATA STRUCTURES ----------
linear = draw_box("Linear DS", 10, 135, "#98DF8A")
nonlinear = draw_box("Non-Linear DS", 60, 135, "#98DF8A")

connect((42,160), (22,141))
connect((42,160), (72,141))

# Linear
static = draw_box("Static", 0, 110, "#C7E9C0")
dynamic = draw_box("Dynamic", 25, 110, "#C7E9C0")

connect((22,135), (12,116))
connect((22,135), (37,116))

# Static children
array = draw_box("Array", -10, 85, "#E5F5E0")
string = draw_box("String", 10, 85, "#E5F5E0")

connect((12,110), (2,91))
connect((12,110), (22,91))

# Dynamic children
dynamic_items = ["Linked List", "Stack", "Queue", "Deque"]
x_pos = 25
for item in dynamic_items:
    child = draw_box(item, x_pos, 85, "#E5F5E0")
    connect((37,110), (x_pos+12,91))
    x_pos += 25

# ---------- ALGORITHMS ----------
categories = {
    "Searching": ["Linear Search", "Binary Search"],
    "Sorting": ["Bubble Sort", "Selection Sort", "Insertion Sort", "Merge Sort", "Quick Sort", "Heap Sort"],
    "Tree Algorithms": ["DFS", "Preorder", "Inorder", "Postorder", "BFS (Level Order)"],
    "Graph Algorithms": ["BFS", "DFS", "Dijkstra", "Bellman-Ford", "Floyd Warshall", "Kruskal", "Prim"],
}

x_start = 110
for cat, subs in categories.items():
    cat_box = draw_box(cat, x_start, 135, "#FDBF6F")
    connect((132,160), (x_start+12,141))

    y_child = 110
    for sub in subs:
        sub_box = draw_box(sub, x_start, y_child, "#FFE0B2")
        connect((x_start+12,135), (x_start+12, y_child+6))
        y_child -= 22

    x_start += 32

# ---------- SAVE ----------
plt.savefig("DSA_Final_Professional_With_Arrows.jpeg",
            dpi=300,
            bbox_inches="tight")
plt.close()

print("Saved as DSA_Final_Professional_With_Arrows.jpeg")
# Out:
# Saved as DSA_Final_Professional_With_Arrows.jpeg

# %%
# array = [1,3,7,12,26,9,122,800]
# target = 12
def liner_search(array,taget):
    n =len(arr)
    for index in range(0,n):
        if array[index]==target:
            return index
    else:
        return -1
        

array = [1,3,7,12,26,9,122,800]

target = 199

result = liner_search(array,target)
print(result)
# Out:
# -1

# %%
def selection_sort(arr):
    n = len(arr)
    
    for i in range(n - 1):
        min_index = i
        
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        
        # Swap the found minimum element with first unsorted element
        arr[i], arr[min_index] = arr[min_index], arr[i]
    
    return arr


# Example
arr = [64, 25, 12, 22, 11]
print("Before sorting:", arr)
print("After sorting:", selection_sort(arr))
# Out:
# Before sorting: [64, 25, 12, 22, 11]
# After sorting: [11, 12, 22, 25, 64]

# %%
def selection_sort(arr):
    n = len(arr)
    
    for i in range(n - 1):
        min_index = i
        
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        
        # Swap
        arr[i], arr[min_index] = arr[min_index], arr[i]
        
        # Print after each outer iteration
        print(f"After iteration {i + 1}: {arr}")
    
    return arr


# Example
arr = [8,4,1,4,6]
print("Before sorting:", arr)
selection_sort(arr)
# Out:
# Before sorting: [8, 4, 1, 4, 6]
# After iteration 1: [1, 4, 8, 4, 6]
# After iteration 2: [1, 4, 8, 4, 6]
# After iteration 3: [1, 4, 4, 8, 6]
# After iteration 4: [1, 4, 4, 6, 8]
# [1, 4, 4, 6, 8]

# %%
len(arr)
# Out:
# 5

# %%
len(arr)-1
# Out:
# 4

# %%
arr = [2,4,1,0,8,5,10,7]
def bubble_sort(arr):
    n = len(arr)
    for i in range(0,n):
        for j in range(0,n-1-i):
            if arr[j] >arr[j+1]:

# %%
arr = [2,4,1,0,8,5,10,7]

def bubble_sort(arr):
    n = len(arr)
    
    for i in range(0, n):
        for j in range(0, n-1-i):
            if arr[j] > arr[j+1]:
                # swap
                arr[j], arr[j+1] = arr[j+1], arr[j]
    
    return arr

print(bubble_sort(arr))
# Out:
# [0, 1, 2, 4, 5, 7, 8, 10]
